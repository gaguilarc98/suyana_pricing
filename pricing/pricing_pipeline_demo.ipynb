# %% [markdown]
# # Pricing Pipeline Demo
#
# This notebook demonstrates the step-by-step execution of the Parametric Drought index pricing pipeline.
# It is fully modularised, meaning each logical step is contained in a separate python script that draws from the `config.yaml`.

# %%
# !python 01_daily_climatology.py

# %% [markdown]
# The daily climatology calculates a historical daily average parameter for our pixels across a baseline block.

# %%
# !python 02_cumulative_anomalies.py

# %% [markdown]
# Next, we calculate the accumulated anomalies over the precise crop-season window for each location.

# %%
# !python 03_triggers_and_losses.py

# %% [markdown]
# Historical metrics let us establish our P1, P5, and P10 triggers and back-test historical losses under this simulated policy.

# %%
# !python 04_bootstrap_aep.py

# %% [markdown]
# By bootstrapping these historical losses, we construct standard Annual Exceedance Probability (AEP) curves.

# %%
# !python 05_pricing_quote.py

# %% [markdown]
# From that distribution and the AAL (Average Annual Loss), we determine the Technical and Commercial Premiums.

# %%
# !python 06_presentation_and_slip.py

# %% [markdown]
# Finally, we conduct programmatic QA Checks ensuring math validity.

# %%
# !python 07_quality_assurance.py
